# %% [markdown]
# # Operations on Singly Linked List

# %% [markdown]
# ### Node Creation

# %%
class Node:
    def __init__(self):
        self.info = None
        self.next = None
node = Node()
print(node)

# %% [markdown]
# ### Linked List Creation

# %%
class LinkedList:
    def __init__(self):
        self.start=None
LL=LinkedList()
print(LL)

# %% [markdown]
# ### Insert values into Linked List

# %%
class Node:
    def __init__(self):
        self.info=None
        self.next=None

class LinkedList:
    def __init__(self):
        self.start=None
    
    def display(self):
        temp=self.start
        while(temp.next!= None):
            print(temp.info,end="-->")
            temp=temp.next
        print(temp.info)
        
LL=LinkedList()
node1 = Node()
node1.info = "India"
node2 = Node()
node2.info = "Pakistan"
node3 = Node()
node3.info = "Bangladesh"
LL.start = node1
node1.next = node2
node2.next = node3
LL.display()
# Out:
# India-->Pakistan-->Bangladesh

# %% [markdown]
# ### Applying Creation, Insertion, Deletion, Searching and Reversal on Linked List

# %%
class Node:
    def __init__(self):
        self.info = None
        self.next = None
        
class Linkedlist:
    def __init__(self):
        self.start = None 
    
    def create(self):
        self.start = None
        while(1):
            node = Node()
            node.info = input("Enter info: ")
            if(self.start == None):
                self.start = node
            else:
                temp.next = node
            temp = node 
            choice = input("Do u want to next node? yes/no : ")
            if(choice=="no"):
                break
        print("Linkedlist created successfully")
        
        
    def insert_at_beginning(self):
        if(self.start == None):
            print("No Linkedlist exists")
        else:
            node = Node()
            node.info = input("Enter element which u want to insert at beginning: ")
            node.next = self.start 
            self.start = node
        print("Element inserted at beginning successfully")
        
    def insert_at_last(self):
        if(self.start == None):
            print("No Linkedlist exists")
        else:
            temp = self.start 
            while(temp.next!=None):
                temp = temp.next 
            node = Node()
            node.info = input("Enter element which u want to insert at last: ")
            temp.next = node
        print("Element inserted at last successfully")
    
    def insert_at_desired_location(self,elem):
        if(self.start == None):
            print("No Linkedlist exists")
        else:
            temp = self.start
            while(temp.next is not None and temp.info!=elem):
                temp =temp.next
            if(temp == None):
                print("No Element found")
            else:
                node=Node()
                node.info = input("Enter element which is to be inserted : ")
                node.next = temp.next
                temp.next = node
        print("Inserted element after node successfully")
            
    def delete_at_beginning(self):
        if(self.start == None):
            print("No Linkedlist exists")
        else:
            self.start = self.start.next
        print("Element in the beginning Deleted successfully")
        
    def deletion_at_last(self):
        if(self.start == None):
            print("No Linkedlist exist")
        else:
            temp = self.start 
            prev = None
            while(temp.next!=None):
                prev = temp
                temp = temp.next
            if(prev is None):
                self.strat = None
            else:
                prev.next = None
        print("Deletion at last is successful")
        
    def deletion_at_desired_location(self,elem):
        if(self.start == None):
            print("No Linkedlist exist")
        else:
            temp = self.start
            prev = None
            while(temp is not None and temp.info!=elem):
                prev = temp
                temp = temp.next
            if(temp is None):
                print("Element is does not exists in LinkedList")
            else:
                if(prev is None):
                    self.start = self.strat.next
                else:
                    prev.next = temp.next
        print("Deletion at desired location is successful")
        
    def search(self,elem):
        if(self.start == None):
            print("No Linkedlist exist")
        else:
            temp = self.start
            while(temp is not None and temp.info!=elem):
                temp = temp.next
            if(temp is not None):
                print("Element found in Linkedlist")
            else:
                print("Element not found in Linkedlist")
                
    def reversal(self):
        if(self.start == None):
            print("No Linkedlist exist")
        else:
            prev = None
            curr = self.start
            while(curr is not None):
                temp = curr.next
                curr.next = prev
                prev = curr
                curr = temp
            self.start = prev
            print("Reversal on Linked List is successful")
            
    def display(self):
        temp = self.start
        while(temp.next!=None):
            print(temp.info,end = "--->")
            temp = temp.next
        print(temp.info)
        print("Linked list is displayed successfully")

# %% [markdown]
# ### User can perform following Functions on Linked List

# %%
def alpha_function():
    LL = Linkedlist()
    while(True): 
        print("""<***************************** LINKEDLIST PROGRAM *****************************>
          1.Linked List Creation
          2.Insert at beginning
          3.Insert at End
          4.Insert at desired location
          5.Deletion at beginning
          6.Deletion at last
          7.Deletion at desired location
          8.Searching
          9.Reversal
          10.Display
          11.Exit""")
        
        choice = int(input("Select your decision: "))
        if(choice==1):
            LL.create()
        elif(choice==2):
            LL.insert_at_beginning()
        elif(choice==3):
            LL.insert_at_last()
        elif(choice==4):
            elem = input("Enter element after which you want to insert next element: ")
            LL.insert_at_desired_location(elem)
        elif(choice==5):
            LL.delete_at_beginning()
        elif(choice==6):
            LL.deletion_at_last()
        elif(choice==7):
            elem = input("Enter element which is to be delete: ")
            LL.deletion_at_desired_location(elem)
        elif(choice==8):
            elem = input("Enter element which you need to find: ")
            LL.search(elem)
        elif(choice==9):
            LL.reversal()
        elif(choice==10):
            LL.display()
        elif(choice==11):
            print("Thank you")
            break
        else:
            print("Please Select correct decision")
alpha_function()
# Out:
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Linked List Creation
#           2.Insert at beginning
#           3.Insert at End
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Reversal
#           10.Display
#           11.Exit
# Select your decision: 1
# Enter info: 56
# Do u want to next node? yes/no : yes
# Enter info: 13
# Do u want to next node? yes/no : no
# Linkedlist created successfully
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Linked List Creation
#           2.Insert at beginning
#           3.Insert at End
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Reversal
#           10.Display
# ...

# %%
alpha_function()
# Out:
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Linked List Creation
#           2.Insert at beginning
#           3.Insert at End
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Reversal
#           10.Display
#           11.Exit
# Select your decision: 1
# Enter info: 13
# Do u want to next node? yes/no : yes
# Enter info: 78
# Do u want to next node? yes/no : yes
# Enter info: 15
# Do u want to next node? yes/no : no
# Linkedlist created successfully
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Linked List Creation
#           2.Insert at beginning
#           3.Insert at End
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
# ...

# %%
alpha_function()
# Out:
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Linked List Creation
#           2.Insert at beginning
#           3.Insert at End
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Reversal
#           10.Display
#           11.Exit
# Select your decision: 1
# Enter info: 56
# Do u want to next node? yes/no : yes
# Enter info: 89
# Do u want to next node? yes/no : yes
# Enter info: 12
# Do u want to next node? yes/no : no
# Linkedlist created successfully
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Linked List Creation
#           2.Insert at beginning
#           3.Insert at End
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
# ...

# %%
alpha_function()
# Out:
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Linked List Creation
#           2.Insert at beginning
#           3.Insert at End
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Reversal
#           10.Display
#           11.Exit
# Select your decision: 1
# Enter info: 56
# Do u want to next node? yes/no : yes
# Enter info: 17
# Do u want to next node? yes/no : yes
# Enter info: 98
# Do u want to next node? yes/no : no
# Linkedlist created successfully
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Linked List Creation
#           2.Insert at beginning
#           3.Insert at End
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
# ...

# %%
alpha_function()
# Out:
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Linked List Creation
#           2.Insert at beginning
#           3.Insert at End
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
#           7.Deletion at desired location
#           8.Searching
#           9.Reversal
#           10.Display
#           11.Exit
# Select your decision: 1
# Enter info: 67
# Do u want to next node? yes/no : yes
# Enter info: 13
# Do u want to next node? yes/no : yes
# Enter info: 90
# Do u want to next node? yes/no : yes
# Enter info: 12
# Do u want to next node? yes/no : no
# Linkedlist created successfully
# <***************************** LINKEDLIST PROGRAM *****************************>
#           1.Linked List Creation
#           2.Insert at beginning
#           3.Insert at End
#           4.Insert at desired location
#           5.Deletion at beginning
#           6.Deletion at last
# ...
